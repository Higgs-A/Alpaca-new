# %% [markdown]
# ***
# # Starting Kit - Black Swan HiggsML Course
# ***

# %%
COLAB = "google.colab" in str(get_ipython())

# %%
if COLAB:
    ! git clone --depth 1 https://github.com/blackSwanCS/Higgs_collaborations.git

    ! git status
    # %cd Higgs_collaborations

# %%
# HiggsML utility package should not be modified
# %pip install HiggsML 0.1.5
# %pip install xgboost
# Out:
# Requirement already satisfied: HiggsML in c:\Users\kirua\OneDrive\Bureau\CS\EI HIGGS new\venv\Lib\site-packages (0.1.5)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement 0.1.5 (from versions: none)
# ERROR: No matching distribution found for 0.1.5
# Requirement already satisfied: xgboost in c:\Users\kirua\OneDrive\Bureau\CS\EI HIGGS new\venv\Lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\Users\kirua\OneDrive\Bureau\CS\EI HIGGS new\venv\Lib\site-packages (from xgboost) (2.4.6)
# Requirement already satisfied: scipy in c:\Users\kirua\OneDrive\Bureau\CS\EI HIGGS new\venv\Lib\site-packages (from xgboost) (1.17.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Imports

# %%
from sys import path
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
from itertools import product
from numpy.random import RandomState
import warnings
import os
import sys

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Directories

# %%
root_dir = os.getcwd()
print("Root directory is", root_dir)
submission_dir = os.path.join(root_dir, "sample_code_submission")

# The directory where results and other outputs from the participant's code will be written
output_dir = os.path.join(root_dir, "sample_result_submission")

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
# Out:
# Root directory is c:\Users\kirua\OneDrive\Bureau\CS\EI HIGGS new\Higgs_collaborations

# %% [markdown]
# ## Import Submission Model
# We import a class named `Model` from the submission file (`model.py`). This `Model` class has the following methods:
# - `init`: receives train set and systematics class as input
# - `fit`: can be used for training
# - `predict`: receives one test set and outputs a dictionary with the following keys
#     - `mu_hat` : predicted mu $\hat{\mu}$
#     - `delta_mu_hat`: $\Delta{\hat{\mu}}$ bound for $\mu$
#     - `p16`: 16th percentile
#     - `p84`: 84th percentile
#
# In this example code, the `Model` class implements a basic model with 2 different model trained to predict the class label.
#
# * 1 XGBoost BDT ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/boosted_decision_tree.py) )
# * 2 Tebsorflow NN  ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/neural_network.py) )
#
# The feature engineering is in where you can include derived quantities and decide which feature should be needed. ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/feature_engineering.py) )
#
# the statistical analysis part is where yoiu write the mu finding calculation using the output of the classifier. ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/statistical_analysis.py) )
#
# If running in Collab, click the folder icon in the left sidebar to open the file browser.

# %%
path.append(submission_dir)
from model import Model

# %% [markdown]
# ## Data
# ### Available data sets
# 1. blackSwan_data
# 2. sample_data
# 3. neurips2024_data

# %%
from HiggsML.datasets import download_dataset

data = download_dataset(
    "blackSwan_data"
)  # change to "blackSwan_data" for the actual data
# Out:
# 2026-06-02 16:00:19,107 - HiggsML.datasets     - INFO     - Handling as dataset name: blackSwan_data
# 2026-06-02 16:00:19,114 - HiggsML.datasets     - INFO     - Current working directory: c:\Users\kirua\OneDrive\Bureau\CS\EI HIGGS new\Higgs_collaborations
# 2026-06-02 16:00:19,114 - HiggsML.datasets     - WARNING  - public_data directory not found
# 2026-06-02 16:00:19,114 - HiggsML.datasets     - WARNING  - FAIR_Universe_HiggsML_data.zip does not exist
# 2026-06-02 16:00:19,114 - HiggsML.datasets     - INFO     - Downloading public data, this may take few minutes
# 2026-06-02 16:06:05,270 - HiggsML.datasets     - INFO     - Extracting blackSwan_data.zip
# 2026-06-02 16:06:07,717 - HiggsML.datasets     - INFO     - Total rows: 2000000
# 2026-06-02 16:06:07,726 - HiggsML.datasets     - INFO     - Test size: 600000

# %% [markdown]
# ### ⚠️ Note:
# The data used here is a small subset of the full data is for demonstration only to get a view of what the data looks like.

# %%
# load train set
data.load_train_set()
data_set = data.get_train_set()
# Out:
# 2026-06-02 16:06:07,896 - HiggsML.datasets     - INFO     - Selected train size: 1400000
# 2026-06-02 16:06:08,709 - HiggsML.datasets     - INFO     - Data loaded successfully

# %% [markdown]
# ***
# ## Visualize the Data Set
# ***

# %%
from tabulate import tabulate

target = data_set["labels"]
weights = data_set["weights"]
detailed_label = data_set["detailed_labels"]
keys = np.unique(detailed_label)


weight_keys = {}
average_weights = {}
for key in keys:
    weight_keys[key] = weights[detailed_label == key]

table_data = []
for key in keys:
    table_data.append(
        [
            key,
            np.sum(weight_keys[key]),
            len(weight_keys[key]),
            np.mean(weight_keys[key]),
        ]
    )

table_data.append(
    [
        "Total Signal",
        np.sum(weights[target == 1]),
        len(weights[target == 1]),
        np.mean(weights[target == 1]),
    ]
)
table_data.append(
    [
        "Total Background",
        np.sum(weights[target == 0]),
        len(weights[target == 0]),
        np.mean(weights[target == 0]),
    ]
)


print("[*] --- Detailed Label Summary")
print(
    tabulate(
        table_data,
        headers=[
            "Detailed Label",
            "Total Weight",
            "Number of events",
            "Average Weight",
        ],
        tablefmt="grid",
    )
)
# Out:
# [*] --- Detailed Label Summary
# +------------------+----------------+--------------------+------------------+
# | Detailed Label   |   Total Weight |   Number of events |   Average Weight |
# +==================+================+====================+==================+
# | diboson          |        382.109 |               3406 |       0.112187   |
# +------------------+----------------+--------------------+------------------+
# | htautau          |        675.897 |             462981 |       0.00145988 |
# +------------------+----------------+--------------------+------------------+
# | ttbar            |       4404.72  |              39293 |       0.112099   |
# +------------------+----------------+--------------------+------------------+
# | ztautau          |     100256     |             894320 |       0.112103   |
# +------------------+----------------+--------------------+------------------+
# | Total Signal     |        675.897 |             462981 |       0.00145988 |
# +------------------+----------------+--------------------+------------------+
# | Total Background |     105043     |             937019 |       0.112103   |
# +------------------+----------------+--------------------+------------------+

# %%
print("\n[*] --- Examples of all features\n")
display(data_set.head())
# Out:
# [*] --- Examples of all features
#    PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  PRI_had_pt  PRI_had_eta  PRI_had_phi  \
# 0   37.472000        0.676       -1.520   46.752998        0.623        1.500
# 1   26.006001       -0.087       -1.412   60.009998       -0.290       -0.099
# 2   20.622999       -0.922       -0.436   41.917999       -1.356        2.524
# 3   48.394001        0.202        0.816   27.916000       -0.552       -2.387
# 4   39.840000       -0.005        1.487   30.997000        1.747        2.681
#
#    PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0          -25.000000              -25.000              -25.000
# 1          134.770996                0.350                2.894
# 2          -25.000000              -25.000              -25.000
# 3          -25.000000              -25.000              -25.000
# 4           73.082001                3.369               -1.286
#
#    PRI_jet_subleading_pt  ...    DER_pt_h  DER_deltaeta_jet_jet  \
# 0                -25.000  ...   30.256184               -25.000
# 1                 49.673  ...  124.359779                 2.009
# 2                -25.000  ...   10.601603               -25.000
# 3                -25.000  ...   10.455322               -25.000
# 4                 31.274  ...   92.074677                 3.370
#
#    DER_mass_jet_jet  DER_prodeta_jet_jet  DER_deltar_had_lep  DER_pt_tot  \
# 0        -25.000000           -25.000000            3.020465   30.256184
# 1        232.705902            -0.580650            1.328600    9.316307
# 2        -25.000000           -25.000000            2.991648   10.601603
# 3        -25.000000           -25.000000            3.171129   10.455322
# 4        254.889191            -0.003369            2.120175    6.207835
#
#    DER_sum_pt DER_pt_ratio_lep_had  DER_met_phi_centrality  \
# 0   84.224998             0.801489                1.365776
# 1  270.459991             0.433361                1.413247
# 2   62.541000             0.491984                1.315526
# 3   76.309998             1.733558               -1.409702
# 4  175.192993             1.285286                1.037429
#
#    DER_lep_eta_centrality
# 0              -25.000000
# 1                0.726747
# 2              -25.000000
# 3              -25.000000
# 4                0.366135
#
# [5 rows x 31 columns]

# %%
print("\n[*] --- Description of all features\n")
display(data_set.describe())
# Out:
# [*] --- Description of all features
#          PRI_lep_pt   PRI_lep_eta   PRI_lep_phi    PRI_had_pt   PRI_had_eta  \
# count  1.400000e+06  1.400000e+06  1.400000e+06  1.400000e+06  1.400000e+06
# mean   3.396482e+01 -1.664071e-03  3.532692e-04  4.310186e+01 -1.059442e-03
# std    1.806436e+01  1.223419e+00  1.813047e+00  2.134356e+01  1.246117e+00
# min    2.000000e+01 -2.500000e+00 -3.142000e+00  2.287700e+01 -2.690000e+00
# 25%    2.395100e+01 -9.520000e-01 -1.568000e+00  3.077000e+01 -9.770000e-01
# 50%    2.901600e+01 -1.000000e-03  1.000000e-03  3.816800e+01 -1.000000e-03
# 75%    3.716600e+01  9.500000e-01  1.572000e+00  4.813200e+01  9.730000e-01
# max    1.101770e+03  2.500000e+00  3.142000e+00  8.452980e+02  2.680000e+00
#
#         PRI_had_phi  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count  1.400000e+06        1.400000e+06         1.400000e+06
# mean  -7.431229e-04        2.039557e+01        -1.315356e+01
# std    1.813856e+00        6.307355e+01         1.255423e+01
# min   -3.142000e+00       -2.500000e+01        -2.500000e+01
# 25%   -1.572000e+00       -2.500000e+01        -2.500000e+01
# 50%    3.000000e-03       -2.500000e+01        -2.500000e+01
# 75%    1.570000e+00        4.706200e+01        -1.560000e-01
# max    3.142000e+00        1.203860e+03         4.991000e+00
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  ...      DER_pt_h  \
# count         1.400000e+06           1.400000e+06  ...  1.400000e+06
# mean         -1.315217e+01          -8.396194e+00  ...  4.182135e+01
# std           1.254495e+01           3.432262e+01  ...  5.431841e+01
# min          -2.500000e+01          -2.500000e+01  ...  1.173875e-02
# 25%          -2.500000e+01          -2.500000e+01  ...  1.094507e+01
# 50%          -2.500000e+01          -2.500000e+01  ...  2.156595e+01
# 75%          -1.780000e-01          -2.500000e+01  ...  4.885020e+01
# max           3.142000e+00           1.001000e+03  ...  1.175087e+03
#
#        DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# count          1.400000e+06      1.400000e+06         1.400000e+06
# mean          -1.887505e+01      5.100177e+01        -1.942000e+01
# std            1.143358e+01      2.382271e+02         1.057919e+01
# min           -2.500000e+01     -2.500000e+01        -2.500000e+01
# 25%           -2.500000e+01     -2.500000e+01        -2.500000e+01
# 50%           -2.500000e+01     -2.500000e+01        -2.500000e+01
# 75%           -2.500000e+01     -2.500000e+01        -2.500000e+01
# max            9.666000e+00      6.555388e+03         2.229731e+01
#
#        DER_deltar_had_lep    DER_pt_tot    DER_sum_pt  DER_pt_ratio_lep_had  \
# count        1.400000e+06  1.400000e+06  1.400000e+06          1.400000e+06
# mean         2.738725e+00  1.806350e+01  1.273698e+02          8.796806e-01
# std          6.103445e-01  1.601432e+01  1.094018e+02          5.094582e-01
# min          5.641427e-01  1.173875e-02  4.304400e+01          3.400616e-02
# 25%          2.509546e+00  8.491425e+00  6.449300e+01          5.891082e-01
# 50%          2.957897e+00  1.439308e+01  8.531300e+01          7.759828e-01
# 75%          3.127119e+00  2.271586e+01  1.433570e+02          1.024202e+00
# max          5.804204e+00  7.199706e+02  2.497039e+03          2.160489e+01
#
#        DER_met_phi_centrality  DER_lep_eta_centrality
# count            1.400000e+06            1.400000e+06
# mean             2.691063e-01           -1.930729e+01
# std              1.217131e+00            1.060158e+01
# min             -1.414214e+00           -2.500000e+01
# 25%             -1.332358e+00           -2.500000e+01
# 50%              9.866624e-01           -2.500000e+01
# 75%              1.385667e+00           -2.500000e+01
# max              1.414214e+00            1.000000e+00
#
# [8 rows x 30 columns]

# %%
from utils import histogram_dataset

# this function is defined in utils.py in the sample_code_submission directory. feel free to modify it as needed

histogram_dataset(
    data_set,
    target,
    weights,
    columns=["PRI_lep_phi", "PRI_met", "DER_mass_vis", "DER_deltaeta_jet_jet"],
)
# Out:
# [*] --- PRI_lep_phi histogram
# [*] --- PRI_met histogram
# [*] --- DER_mass_vis histogram
# [*] --- DER_deltaeta_jet_jet histogram

# %%
import seaborn as sns

sns.set_theme(rc={"figure.figsize": (10, 10)}, style="whitegrid")

caption = ["Signal feature", "Background feature"]

for i in range(2):

    dfplot = pd.DataFrame(
        data_set,
        columns=[
            "PRI_lep_phi",
            "PRI_met",
            "DER_pt_ratio_lep_had",
            "DER_deltaeta_jet_jet",
        ],
    )

    print(caption[i], " correlation matrix")
    corrMatrix = dfplot[target == i].corr()
    sns.heatmap(corrMatrix, annot=True)
    plt.title("Correlation matrix of features")
    plt.show()

del dfplot
# Out:
# Signal feature  correlation matrix
# Background feature  correlation matrix

# %%
from HiggsML.visualization import stacked_histogram

stacked_histogram(data_set, target, weights, detailed_label, "PRI_jet_subleading_pt")
# Out:
# keys ['diboson' 'htautau' 'ttbar' 'ztautau']
# keys 2 dict_keys(['diboson', 'htautau', 'ttbar', 'ztautau'])
# htautau (30,)

# %%
from HiggsML.visualization import pair_plots

# Show data summary
pair_plots(
    data_set,
    target,
    sample_size=100,
    columns=[
        "PRI_lep_phi",
        "PRI_met",
        "DER_lep_eta_centrality",
        "DER_deltaeta_jet_jet",
    ],
)

# %% [markdown]
# ### Ingestion

# %%
from HiggsML.ingestion import Ingestion

ingestion = Ingestion(data)

# %%
# initialize submission
ingestion.init_submission(Model,"BDT")
# Out:
# 2026-06-02 16:06:56,750 - HiggsML.ingestion    - INFO     - Initializing Submmited Model
# 2026-06-02 16:06:56,756 - HiggsML.datasets     - INFO     - Selected train size: 5000
# 2026-06-02 16:06:57,301 - HiggsML.datasets     - INFO     - Data loaded successfully
# 2026-06-02 16:06:57,320 - HiggsML.datasets     - INFO     - Selected train size: 5000
# Training Data:  (5000, 28)
# Training Labels:  (5000,)
# Training Weights:  (5000,)
# sum_signal_weights:  664.1374016251686
# sum_bkg_weights:  105054.86259837485
# 2026-06-02 16:06:57,843 - HiggsML.datasets     - INFO     - Data loaded successfully
# 2026-06-02 16:06:57,864 - HiggsML.datasets     - INFO     - Selected train size: 5000
# Valid Data:  (5000, 28)
# Valid Labels:  (5000,)
# Valid Weights:  (5000,)
# sum_signal_weights:  665.327449175842
# sum_bkg_weights:  105053.67255082418
# 2026-06-02 16:06:58,374 - HiggsML.datasets     - INFO     - Data loaded successfully
# Holdout Data:  (5000, 28)
# Holdout Labels:  (5000,)
# Holdout Weights:  (5000,)
# sum_signal_weights:  671.8875070749627
# sum_bkg_weights:  105047.11249292505
#
#
# Training Data:  (5000, 28)
# DEBUG: model_type = 'BDT'
#  Model is BDT

# %%
# fit submission
ingestion.fit_submission()
# Out:
# 2026-06-02 16:06:58,802 - HiggsML.ingestion    - INFO     - Calling fit method of submitted model
# score shape before threshold (4568,)
# score shape after threshold (4568,)
# saved_info {'beta': np.float64(13752.797092855802), 'gamma': np.float64(442.92256091205525), 'tes_fit': <function tes_fitter.<locals>.fit_function at 0x00000205E69DEC00>, 'jes_fit': <function jes_fitter.<locals>.fit_function at 0x00000205E69DF740>}
# Train Results:
# 	 mu_hat  :  -28.869156080829065
# 	 del_mu_stat  :  0.2689991481701225
# 	 del_mu_sys  :  0.0
# 	 del_mu_tot  :  0.2689991481701225
# Holdout Results:
# 	 mu_hat  :  0.9999999999999992
# 	 del_mu_stat  :  0.2689991481701225
# 	 del_mu_sys  :  0.0
# 	 del_mu_tot  :  0.2689991481701225
# Valid Results:
# 	 mu_hat  :  -1.1577526451690168
# 	 del_mu_stat  :  0.2689991481701225
# 	 del_mu_sys  :  0.0
# 	 del_mu_tot  :  0.2689991481701225
# [*] --- score histogram
# keys ['diboson' 'htautau' 'ttbar' 'ztautau']
# keys 2 dict_keys(['diboson', 'htautau', 'ttbar', 'ztautau'])
# htautau (30,)

# %%
# load test set
data.load_test_set()
# Out:
# 2026-06-02 16:07:05,487 - HiggsML.datasets     - INFO     - Data loaded successfully
# 2026-06-02 16:07:05,904 - HiggsML.datasets     - INFO     - Test data loaded successfully

# %% [markdown]
# ### Test Settings
# The Test setting sets the test conditions in ingestion.
# This includes what systematics you want and how many psuedo experiments you want.

# %%
test_settings = {
    "systematics": {  # Systematics to use
        "tes": False,  # tau energy scale
        "jes": False,  # jet energy scale
        "soft_met": False,  # soft term in MET
        "ttbar_scale": False,  # W boson scale factor
        "diboson_scale": False,  # Diboson scale factor
        "bkg_scale": False,  # Background scale factor
    },
    "num_pseudo_experiments": 500,  # Number of pseudo-experiments to run per set
    "num_of_sets": 1,  # Number of sets of pseudo-experiments to run
}

RANDOM_SEED = 42

random_state = np.random.RandomState(RANDOM_SEED)
test_settings["ground_truth_mus"] = (
    random_state.uniform(0.1, 3, test_settings["num_of_sets"])
).tolist()

random_settings_file = os.path.join(output_dir, "test_settings.json")
with open(random_settings_file, "w") as f:
    json.dump(test_settings, f)

# %%
# predict submission
ingestion.predict_submission(test_settings)
# Out:
# 2026-06-02 16:07:05,987 - HiggsML.ingestion    - INFO     - Calling predict method of submitted model with seed: 31415
# Test Results:  {'mu_hat': np.float64(0.6258495990210752), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.070622607635363), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.1517260873002607), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5016743935703857), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9825710983157833), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8990350510125921), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.2489833572827171), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0209525254550873), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8877463959716203), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.1835091580450807), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6371382540620469), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8448495068159276), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0683648766271687), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9487051331928679), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4768393524802478), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7274474943898211), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8809732029470373), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4994166625621913), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.48587027651302517), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.668746488176768), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.528767165668718), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8177567347175954), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5603753997834389), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6235918680128808), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8132412727012066), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9803133673075889), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7996948866520405), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.48361254550483085), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9080659750453696), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7906639626192631), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5468290137342727), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7545402664881534), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.1135194967910558), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6235918680128808), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9803133673075889), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6958392602751002), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.2623549067017841), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.853880430848705), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.032241180496059), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9961174843649494), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7093856463242663), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5152207796195518), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.056901384956097784), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.752282535479959), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0006329463813382), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9306432851273131), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9012927820207864), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.993859753356755), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6348805230538526), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9103237060535638), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7116433773324606), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9825710983157833), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9712824432748115), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7206743013652381), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.892261857988009), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6416537160784357), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.43845792534094374), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4520043113901099), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.2760761293810494), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.2489833572827171), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4790970834884421), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6619732951521848), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.330261673577714), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8403340447995389), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.21494255552970262), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7996948866520405), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4994166625621913), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0277257184796704), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5694063238162164), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.853880430848705), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.46780842844747034), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8200144657257897), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6371382540620469), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.612303212971909), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5852104408735768), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8403340447995389), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.993859753356755), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8177567347175954), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7026124532996832), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.27138583073456146), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5490867447424671), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5219939726441348), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6326227920456583), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4790970834884421), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6958392602751002), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.993859753356755), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.38878784316066795), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6393959850702413), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7026124532996832), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4949012005458026), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8019526176602348), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8900041269798147), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6168186749882978), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7590557285045421), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0367566425124477), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5964990959145485), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7409938804389873), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.892261857988009), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8064680796766236), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9893442913403663), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.43620019433274937), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7364784184225985), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.528767165668718), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9712824432748115), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8516226998405106), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7116433773324606), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8109835416930122), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6258495990210752), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.1315813448566105), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.400251334831739), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0412721045288365), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.312199825512159), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.815499003709401), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.109004034774667), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8900041269798147), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.42265380828358323), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7297052253980155), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.3325194045859081), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9509628642010622), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9757979052912001), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.46329296643108164), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.267045205348272), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8064680796766236), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.14721062528387197), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6664887571685736), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9261278231109243), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9351587471437018), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0209525254550873), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4294270013081663), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.33911776098039215), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8629113548814824), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8267876587503727), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7793753075782913), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8380763137913445), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.427169270299972), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.533457464315206), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7229320323734324), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7432516114471817), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7838907695946801), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7884062316110687), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0728803386435575), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.822272196733984), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6393959850702413), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.09754054310359617), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.43394246332455505), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7432516114471817), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9893442913403663), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4068496912262228), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9757979052912001), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8900041269798147), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5987568269227429), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7297052253980155), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.612303212971909), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8403340447995389), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.32331364392303164), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6552001021276018), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8267876587503727), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7229320323734324), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6371382540620469), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8900041269798147), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8335608517749559), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6077877509555204), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.2918802464384098), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0841689936845291), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6958392602751002), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.36621053307872437), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.18333432141498165), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7567979974963478), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8651690858896768), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7003547222914889), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6664887571685736), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.777117576570097), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7342206874144042), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7500248044717647), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.21720028653789697), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.20139616948053649), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9577360572256454), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.357179609045947), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.36169507106233567), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.43394246332455505), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5242517036523292), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.3799317557579898), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.325571374931226), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8267876587503727), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.140612268889388), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6032722889391317), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5964990959145485), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.777117576570097), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7861485006028743), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4045919602180284), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8290453897585671), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.018694794446893), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5806949788571881), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7026124532996832), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.48587027651302517), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9148391680699526), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7500248044717647), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7545402664881534), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.242210164258134), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5603753997834389), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.29396314081650504), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9735401742830058), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6077877509555204), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6890660672505171), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6281073300292696), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7003547222914889), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6348805230538526), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.2465507896444236), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4068496912262228), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.707127915316072), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.892261857988009), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5852104408735768), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6010145579309373), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6484269091030187), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.08173642604623568), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8787154719388429), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8042103486684292), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5919836338981599), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8245299277421784), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9916020223485607), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.21268482452150828), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.1699627719959147), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.39781876719344533), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8651690858896768), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.1268910462101228), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5716640548244106), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9848288293239776), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.29847860283289374), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9351587471437018), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7838907695946801), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8832309339552317), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0841689936845291), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.133839075864805), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6935815292669059), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.31654045089844857), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4542620423983042), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7906639626192631), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5016743935703857), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7409938804389873), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5400558207096897), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5626331307916332), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5852104408735768), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.41813834626719454), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5107053176031631), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8358185827831501), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9374164781518961), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5310248966769123), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7658289215291252), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6913237982587115), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5400558207096897), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6393959850702413), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9961174843649494), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7974371556438461), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9351587471437018), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4294270013081663), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0096638704141154), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.777117576570097), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.612303212971909), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0977153797336954), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5423135517178841), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7613134595127364), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5852104408735768), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.3076843634957702), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# ...
# Test Results:  {'mu_hat': np.float64(1.06384941461078), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9757979052912001), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8877463959716203), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8742000099224542), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.3752414571115018), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5964990959145485), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.1135194967910558), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9012927820207864), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4045919602180284), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.025467987471476), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0344989115042533), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.5018492302004849), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8674268168978712), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4949012005458026), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8900041269798147), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5919836338981599), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.528767165668718), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7500248044717647), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.668746488176768), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6258495990210752), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.29170540980831067), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4023342292098341), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8854886649634259), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.535540358693301), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8403340447995389), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7048701843078776), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9848288293239776), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9757979052912001), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.2826744857755333), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6958392602751002), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.707127915316072), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5423135517178841), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7274474943898211), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9645092502502284), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.0728803386435575), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7974371556438461), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.668746488176768), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.3526641470295583), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5761795168407994), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5942413649063543), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.46103523542288727), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5016743935703857), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4790970834884421), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.573921785832605), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6371382540620469), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8200144657257897), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8403340447995389), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7929216936274575), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7658289215291252), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.6531172077495067), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.48812800752121954), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7319629564062099), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.3347771355941025), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8019526176602348), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9599937882338397), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.4994166625621913), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9396742091600905), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.2510662516608123), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.962251519242034), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7116433773324606), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8313031207667615), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.2015710061106357), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7048701843078776), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6439114470866301), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6010145579309373), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5603753997834389), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.43845792534094374), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.955478326217451), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6552001021276018), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.5581176687752445), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9509628642010622), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6010145579309373), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.8313031207667615), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.1359219702429002), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.1677050409877203), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.92387009210273), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.1473854619139712), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.9374164781518961), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.039014373520642), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6416537160784357), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.7184165703570438), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6913237982587115), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.34814868501316953), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6235918680128808), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(0.6190764059964922), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.070622607635363), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}
# Test Results:  {'mu_hat': np.float64(1.172220503004109), 'del_mu_stat': np.float64(0.2689991481701225), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.2689991481701225)}

# %%
ingestion.process_results_dict()

# %%
# save result
ingestion.save_result(output_dir)

# %% [markdown]
# ## Score
# 1. Compute Scores
# 2. Visualize Scores

# %%
from HiggsML.score import Scoring

# %%
# Initialize Score
score = Scoring()

# %%
print(output_dir)
score.load_ingestion_results(prediction_dir=output_dir, score_dir=output_dir)
# Out:
# 2026-06-02 16:13:10,323 - HiggsML.score        - INFO     - Read ingestion results from c:\Users\kirua\OneDrive\Bureau\CS\EI HIGGS new\Higgs_collaborations\sample_result_submission
# c:\Users\kirua\OneDrive\Bureau\CS\EI HIGGS new\Higgs_collaborations\sample_result_submission

# %%
# Compute Score
score.compute_scores(test_settings)
# Out:
# 2026-06-02 16:13:10,342 - HiggsML.score        - INFO     - Computing scores
# [✔]

# %%
from HiggsML.visualization import visualize_scatter

# Visualize scatter plot of ground truth mu and predicted mu
visualize_scatter(
    ingestion_result_dict=ingestion.results_dict,
    ground_truth_mus=test_settings["ground_truth_mus"],
)

# %%
# !python -m HiggsML.score --prediction $output_dir --output $output_dir
# Out:
# ############################################
# ### Scoring Program
# ############################################
# usage: score.py [-h] [--prediction PREDICTION] [--output OUTPUT]
#                 [--reference REFERENCE] [--codabench]
# score.py: error: unrecognized arguments: HIGGS new\Higgs_collaborations\sample_result_submission HIGGS new\Higgs_collaborations\sample_result_submission

# %%
import matplotlib.pyplot as plt
import numpy as np
from HiggsML.systematics import systematics
from sample_code_submission.systematic_analysis import tes_fitter, jes_fitter




my_fit_function = tes_fitter(model, eval_set, tes_variations=np.array([0.9, 1.0, 1.1]))



# --- ÉTAPE 1 : Générer les scores ---
# On calcule le score nominal (sans variation)
syst_nom = systematics(eval_set, tes=1.0)
score_nom = model.predict(syst_nom["data"])

# On calcule le score avec une grosse variation (ex: TES +10% pour bien voir l'effet)
syst_up = systematics(eval_set, tes=1.10)
score_up = model.predict(syst_up["data"])

# --- ÉTAPE 2 : Tracer les histogrammes ---
plt.figure(figsize=(8, 6)) # Taille de l'image

# Histogramme Nominal (Noir, ligne continue)
plt.hist(score_nom, bins=50, range=(0, 1), histtype='step', 
         color='black', label='Nominal (TES = 1.0)', linewidth=2)

# Histogramme Modifié (Rouge, pointillés)
plt.hist(score_up, bins=50, range=(0, 1), histtype='step', 
         color='red', linestyle='--', label='TES Up (TES = 1.10)', linewidth=2)

plt.title("Impact de l'incertitude TES sur les scores du modèle")
plt.xlabel("Score du Modèle (0 = Bruit de fond, 1 = Boson de Higgs)")
plt.ylabel("Nombre d'événements")
plt.legend() # Affiche la légende
plt.grid(True, alpha=0.3) # Ajoute un quadrillage léger
plt.show()


# --- 1. On entraîne ton fitter ---
# Ta fonction s'exécute sur 3 valeurs par exemple
my_fit_function = tes_fitter(model, eval_set, tes_variations=np.array([0.9, 1.0, 1.1]))

# --- 2. On prépare l'histogramme de base (TES=1.0) ---
syst_base = systematics(eval_set, tes=1.0)
score_base = model.predict(syst_base["data"])
hist_base, bins_edges = np.histogram(score_base, bins=100, range=(0, 1))

# --- 3. On utilise TA fonction pour PRÉDIRE l'histogramme pour TES=1.05 ---
# Ton polynôme fait le calcul instantanément (sans utiliser l'IA)
hist_predit = my_fit_function(hist_base, 1.05)

# --- 4. On calcule le VRAI histogramme pour TES=1.05 avec l'IA (pour comparer) ---
syst_vrai = systematics(eval_set, tes=1.05)
score_vrai = model.predict(syst_vrai["data"])
hist_vrai, _ = np.histogram(score_vrai, bins=100, range=(0, 1))

# --- 5. On dessine ! ---
plt.figure(figsize=(10, 6))

# Pour tracer des lignes "façon histogramme" avec un tableau 1D, on utilise le centre des bacs (bins)
bin_centers = 0.5 * (bins_edges[:-1] + bins_edges[1:])

# Le Vrai calculé par l'IA (Ligne épaisse grise)
plt.plot(bin_centers, hist_vrai, label='VRAI calculé par l\'IA (TES=1.05)', 
         color='lightgray', linewidth=4, drawstyle='steps-mid')

# Ta Prédiction (Ligne rouge pointillée par-dessus)
plt.plot(bin_centers, hist_predit, label='PRÉDIT par ta fonction Fit', 
         color='red', linestyle='--', linewidth=2, drawstyle='steps-mid')

plt.title("Validation du Fitting mathématique vs Réalité")
plt.xlabel("Score")
plt.ylabel("Événements par bin")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 9
#       5
#       6
#       7
#       8
# ----> 9 my_fit_function = tes_fitter(model, eval_set, tes_variations=np.array([0.9, 1.0, 1.1]))
#      10
#      11
#      12
#
# NameError: name 'model' is not defined
