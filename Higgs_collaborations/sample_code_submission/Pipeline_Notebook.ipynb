# %% [markdown]
# ***
# # Pipeline Notebook
# ***

# %%
COLAB = "google.colab" in str(get_ipython())

# %%
if COLAB:
    # !rm -rf Higgs_collaborations
    # !git clone https://github.com/Higgs-A/Alpaca-new.git
    # %cd Alpaca-new
    # %cd Higgs_collaborations

    # !git checkout dev
    # !git pull

# %%
# HiggsML utility package should not be modified
# %pip install HiggsML==0.1.5
# %pip install xgboost
# Out:
# Requirement already satisfied: HiggsML==0.1.5 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (0.1.5)
# Collecting argparse>=1.4.0 (from HiggsML==0.1.5)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: matplotlib>=3.8.0 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from HiggsML==0.1.5) (3.10.9)
# Requirement already satisfied: mpld3>=0.5.8 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from HiggsML==0.1.5) (0.5.12)
# Requirement already satisfied: numpy>=1.26.4 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from HiggsML==0.1.5) (2.4.6)
# Requirement already satisfied: pandas>=2.2.2 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from HiggsML==0.1.5) (3.0.3)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from HiggsML==0.1.5) (24.0.0)
# Requirement already satisfied: requests>=2.31.0 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from HiggsML==0.1.5) (2.34.2)
# Requirement already satisfied: scikit-learn>=1.4.2 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from HiggsML==0.1.5) (1.8.0)
# Requirement already satisfied: seaborn>=0.13.1 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from HiggsML==0.1.5) (0.13.2)
# Requirement already satisfied: tabulate>=0.9.0 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from HiggsML==0.1.5) (0.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from matplotlib>=3.8.0->HiggsML==0.1.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from matplotlib>=3.8.0->HiggsML==0.1.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from matplotlib>=3.8.0->HiggsML==0.1.5) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from matplotlib>=3.8.0->HiggsML==0.1.5) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from matplotlib>=3.8.0->HiggsML==0.1.5) (26.2)
# Requirement already satisfied: pillow>=8 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from matplotlib>=3.8.0->HiggsML==0.1.5) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from matplotlib>=3.8.0->HiggsML==0.1.5) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from matplotlib>=3.8.0->HiggsML==0.1.5) (2.9.0.post0)
# Requirement already satisfied: jinja2 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from mpld3>=0.5.8->HiggsML==0.1.5) (3.1.6)
# Requirement already satisfied: tzdata in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from pandas>=2.2.2->HiggsML==0.1.5) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->HiggsML==0.1.5) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from requests>=2.31.0->HiggsML==0.1.5) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from requests>=2.31.0->HiggsML==0.1.5) (3.17)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from requests>=2.31.0->HiggsML==0.1.5) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from requests>=2.31.0->HiggsML==0.1.5) (2026.5.20)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from scikit-learn>=1.4.2->HiggsML==0.1.5) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from scikit-learn>=1.4.2->HiggsML==0.1.5) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from scikit-learn>=1.4.2->HiggsML==0.1.5) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from jinja2->mpld3>=0.5.8->HiggsML==0.1.5) (3.0.3)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: xgboost in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from xgboost) (2.4.6)
# Requirement already satisfied: scipy in c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages (from xgboost) (1.17.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Imports

# %%
from sys import path
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
from itertools import product
from numpy.random import RandomState
import warnings
import os
import sys
import HiggsML
import xgboost

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Directories

# %%
root_dir = os.getcwd()
print("Root directory is", root_dir)
submission_dir = os.path.join(root_dir, "sample_code_submission")

# The directory where results and other outputs from the participant's code will be written
output_dir = os.path.join(root_dir, "sample_result_submission")

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
# Out:
# Root directory is c:\Users\noahl\Documents\EI_PP\Alpaca-new\Higgs_collaborations\sample_code_submission

# %% [markdown]
# ## Import Submission Model
# We import a class named `Model` from the submission file (`model.py`). This `Model` class has the following methods:
# - `init`: receives train set and systematics class as input
# - `fit`: can be used for training
# - `predict`: receives one test set and outputs a dictionary with the following keys
#     - `mu_hat` : predicted mu $\hat{\mu}$
#     - `delta_mu_hat`: $\Delta{\hat{\mu}}$ bound for $\mu$
#     - `p16`: 16th percentile
#     - `p84`: 84th percentile
#
# In this example code, the `Model` class implements a basic model with 2 different model trained to predict the class label.
#
# * 1 XGBoost BDT ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/boosted_decision_tree.py) )
# * 2 Tebsorflow NN  ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/neural_network.py) )
#
# The feature engineering is in where you can include derived quantities and decide which feature should be needed. ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/feature_engineering.py) )
#
# the statistical analysis part is where yoiu write the mu finding calculation using the output of the classifier. ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/statistical_analysis.py) )
#
# If running in Collab, click the folder icon in the left sidebar to open the file browser.

# %%
path.append(submission_dir)
from model import Model

# %% [markdown]
# ## Data
# ### Available data sets
# 1. blackSwan_data
# 2. sample_data
# 3. neurips2024_data

# %%
from HiggsML.datasets import download_dataset

data = download_dataset(
    "blackSwan_data"
)  # change to "blackSwan_data" for the actual data
# Out:
# 2026-06-05 11:31:48,190 - HiggsML.datasets     - INFO     - Handling as dataset name: blackSwan_data
# 2026-06-05 11:31:48,192 - HiggsML.datasets     - INFO     - Current working directory: c:\Users\noahl\Documents\EI_PP\Alpaca-new\Higgs_collaborations\sample_code_submission
# 2026-06-05 11:31:48,194 - HiggsML.datasets     - WARNING  - public_data directory not found
# 2026-06-05 11:31:48,197 - HiggsML.datasets     - INFO     - public_data.zip already exists
# 2026-06-05 11:31:48,199 - HiggsML.datasets     - INFO     - Extracting blackSwan_data.zip
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 from HiggsML.datasets import download_dataset
#       2
# ----> 3 data = download_dataset(
#       4     "blackSwan_data"
#       5 )  # change to "blackSwan_data" for the actual data
#
# File c:\Users\noahl\Documents\EI_PP\venv\Lib\site-packages\HiggsML\datasets.py:360, in download_dataset(input_str)
#     358 # Extract public_data.zip
#     359 logger.info(f"Extracting {name}.zip")
# --> 360 with ZipFile(public_data_zip_path, "r") as zip_ref:
#     361     zip_ref.extractall(public_data_folder_path)
#     363 return Data(public_data_folder_path)
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1385, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1383 try:
#    1384     if mode == 'r':
# -> 1385         self._RealGetContents()
#    1386     elif mode in ('w', 'x'):
#    1387         # set the modified flag so central directory gets written
#    1388         # even if no files are added to the archive
#    1389         self._didModify = True
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1452, in ZipFile._RealGetContents(self)
#    1450     raise BadZipFile("File is not a zip file")
#    1451 if not endrec:
# -> 1452     raise BadZipFile("File is not a zip file")
#    1453 if self.debug > 1:
#    1454     print(endrec)
#
# BadZipFile: File is not a zip file

# %% [markdown]
# ### ⚠️ Note:
# The data used here is a small subset of the full data is for demonstration only to get a view of what the data looks like.

# %%
# load train set
data.load_train_set()
data_set = data.get_train_set()
print(data_set.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # load train set
# ----> 2 data.load_train_set()
#       3 data_set = data.get_train_set()
#       4 print(data_set.columns)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ***
# ## Visualize the Data Set
# ***

# %%
from tabulate import tabulate

target = data_set["labels"]
weights = data_set["weights"]
detailed_label = data_set["detailed_labels"]
keys = np.unique(detailed_label)


weight_keys = {}
average_weights = {}
for key in keys:
    weight_keys[key] = weights[detailed_label == key]

table_data = []
for key in keys:
    table_data.append(
        [
            key,
            np.sum(weight_keys[key]),
            len(weight_keys[key]),
            np.mean(weight_keys[key]),
        ]
    )

table_data.append(
    [
        "Total Signal",
        np.sum(weights[target == 1]),
        len(weights[target == 1]),
        np.mean(weights[target == 1]),
    ]
)
table_data.append(
    [
        "Total Background",
        np.sum(weights[target == 0]),
        len(weights[target == 0]),
        np.mean(weights[target == 0]),
    ]
)


print("[*] --- Detailed Label Summary")
print(
    tabulate(
        table_data,
        headers=[
            "Detailed Label",
            "Total Weight",
            "Number of events",
            "Average Weight",
        ],
        tablefmt="grid",
    )
)
# Out:
# [*] --- Detailed Label Summary
# +------------------+----------------+--------------------+------------------+
# | Detailed Label   |   Total Weight |   Number of events |   Average Weight |
# +==================+================+====================+==================+
# | diboson          |        382.109 |               3406 |       0.112187   |
# +------------------+----------------+--------------------+------------------+
# | htautau          |        675.897 |             462981 |       0.00145988 |
# +------------------+----------------+--------------------+------------------+
# | ttbar            |       4404.72  |              39293 |       0.112099   |
# +------------------+----------------+--------------------+------------------+
# | ztautau          |     100256     |             894320 |       0.112103   |
# +------------------+----------------+--------------------+------------------+
# | Total Signal     |        675.897 |             462981 |       0.00145988 |
# +------------------+----------------+--------------------+------------------+
# | Total Background |     105043     |             937019 |       0.112103   |
# +------------------+----------------+--------------------+------------------+

# %%
print("\n[*] --- Examples of all features\n")
display(data_set.head())
# Out:
# [*] --- Examples of all features
#    PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  PRI_had_pt  PRI_had_eta  PRI_had_phi  \
# 0   37.472000        0.676       -1.520   46.752998        0.623        1.500
# 1   26.006001       -0.087       -1.412   60.009998       -0.290       -0.099
# 2   20.622999       -0.922       -0.436   41.917999       -1.356        2.524
# 3   48.394001        0.202        0.816   27.916000       -0.552       -2.387
# 4   39.840000       -0.005        1.487   30.997000        1.747        2.681
#
#    PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0          -25.000000              -25.000              -25.000
# 1          134.770996                0.350                2.894
# 2          -25.000000              -25.000              -25.000
# 3          -25.000000              -25.000              -25.000
# 4           73.082001                3.369               -1.286
#
#    PRI_jet_subleading_pt  ...    DER_pt_h  DER_deltaeta_jet_jet  \
# 0                -25.000  ...   30.256184               -25.000
# 1                 49.673  ...  124.359779                 2.009
# 2                -25.000  ...   10.601603               -25.000
# 3                -25.000  ...   10.455322               -25.000
# 4                 31.274  ...   92.074677                 3.370
#
#    DER_mass_jet_jet  DER_prodeta_jet_jet  DER_deltar_had_lep  DER_pt_tot  \
# 0        -25.000000           -25.000000            3.020465   30.256184
# 1        232.705902            -0.580650            1.328600    9.316307
# 2        -25.000000           -25.000000            2.991648   10.601603
# 3        -25.000000           -25.000000            3.171129   10.455322
# 4        254.889191            -0.003369            2.120175    6.207835
#
#    DER_sum_pt DER_pt_ratio_lep_had  DER_met_phi_centrality  \
# 0   84.224998             0.801489                1.365776
# 1  270.459991             0.433361                1.413247
# 2   62.541000             0.491984                1.315526
# 3   76.309998             1.733558               -1.409702
# 4  175.192993             1.285286                1.037429
#
#    DER_lep_eta_centrality
# 0              -25.000000
# 1                0.726747
# 2              -25.000000
# 3              -25.000000
# 4                0.366135
#
# [5 rows x 31 columns]

# %%
print("\n[*] --- Description of all features\n")
display(data_set.describe())
# Out:
# [*] --- Description of all features
#          PRI_lep_pt   PRI_lep_eta   PRI_lep_phi    PRI_had_pt   PRI_had_eta  \
# count  1.400000e+06  1.400000e+06  1.400000e+06  1.400000e+06  1.400000e+06
# mean   3.396482e+01 -1.664071e-03  3.532688e-04  4.310186e+01 -1.059442e-03
# std    1.805632e+01  1.223061e+00  1.812455e+00  2.133130e+01  1.245722e+00
# min    2.000000e+01 -2.500000e+00 -3.142000e+00  2.287700e+01 -2.690000e+00
# 25%    2.395100e+01 -9.520000e-01 -1.568000e+00  3.077000e+01 -9.770000e-01
# 50%    2.901600e+01 -1.000000e-03  1.000000e-03  3.816800e+01 -1.000000e-03
# 75%    3.716600e+01  9.500000e-01  1.572000e+00  4.813200e+01  9.730000e-01
# max    1.101770e+03  2.500000e+00  3.142000e+00  8.452980e+02  2.680000e+00
#
#         PRI_had_phi  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count  1.400000e+06        1.400000e+06         1.400000e+06
# mean  -7.431224e-04        2.039557e+01        -1.315356e+01
# std    1.813313e+00        6.295906e+01         1.259517e+01
# min   -3.142000e+00       -2.500000e+01        -2.500000e+01
# 25%   -1.572000e+00       -2.500000e+01        -2.500000e+01
# 50%    3.000000e-03       -2.500000e+01        -2.500000e+01
# 75%    1.570000e+00        4.706200e+01        -1.560000e-01
# max    3.142000e+00        1.203860e+03         4.991000e+00
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  ...      DER_pt_h  \
# count         1.400000e+06           1.400000e+06  ...  1.400000e+06
# mean         -1.315217e+01          -8.396195e+00  ...  4.182135e+01
# std           1.258585e+01           3.418907e+01  ...  5.430045e+01
# min          -2.500000e+01          -2.500000e+01  ...  1.173875e-02
# 25%          -2.500000e+01          -2.500000e+01  ...  1.094507e+01
# 50%          -2.500000e+01          -2.500000e+01  ...  2.156595e+01
# 75%          -1.780000e-01          -2.500000e+01  ...  4.885020e+01
# max           3.142000e+00           1.001000e+03  ...  1.175087e+03
#
#        DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# count          1.400000e+06      1.400000e+06         1.400000e+06
# mean          -1.887505e+01      5.100177e+01        -1.941999e+01
# std            1.150126e+01      2.375393e+02         1.052948e+01
# min           -2.500000e+01     -2.500000e+01        -2.500000e+01
# 25%           -2.500000e+01     -2.500000e+01        -2.500000e+01
# 50%           -2.500000e+01     -2.500000e+01        -2.500000e+01
# 75%           -2.500000e+01     -2.500000e+01        -2.500000e+01
# max            9.666000e+00      6.555388e+03         2.229731e+01
#
#        DER_deltar_had_lep    DER_pt_tot    DER_sum_pt  DER_pt_ratio_lep_had  \
# count        1.400000e+06  1.400000e+06  1.400000e+06          1.400000e+06
# mean         2.738726e+00  1.806350e+01  1.273698e+02          8.796806e-01
# std          6.101729e-01  1.600541e+01  1.093643e+02          5.091473e-01
# min          5.641427e-01  1.173875e-02  4.304400e+01          3.400616e-02
# 25%          2.509546e+00  8.491425e+00  6.449300e+01          5.891082e-01
# 50%          2.957897e+00  1.439308e+01  8.531300e+01          7.759828e-01
# 75%          3.127119e+00  2.271586e+01  1.433570e+02          1.024202e+00
# max          5.804204e+00  7.199706e+02  2.497039e+03          2.160489e+01
#
#        DER_met_phi_centrality  DER_lep_eta_centrality
# count            1.400000e+06            1.400000e+06
# mean             2.691063e-01           -1.930729e+01
# std              1.215709e+00            1.053709e+01
# min             -1.414214e+00           -2.500000e+01
# 25%             -1.332358e+00           -2.500000e+01
# 50%              9.866624e-01           -2.500000e+01
# 75%              1.385667e+00           -2.500000e+01
# max              1.414214e+00            1.000000e+00
#
# [8 rows x 30 columns]

# %%
from utils import histogram_dataset

# this function is defined in utils.py in the sample_code_submission directory. feel free to modify it as needed

histogram_dataset(
    data_set,
    target,
    weights,
    columns=["PRI_lep_phi", "PRI_met", "DER_mass_vis", "DER_deltaeta_jet_jet"],
)
# Out:
# [*] --- PRI_lep_phi histogram
# [*] --- PRI_met histogram
# [*] --- DER_mass_vis histogram
# [*] --- DER_deltaeta_jet_jet histogram

# %%
import seaborn as sns
from feature_analysis import feature_corrilations, feature_signal_background_correlations
from HiggsML.datasets import Data

feature_corrilations(data,True)
feature_signal_background_correlations(data,True)
# Out:
# Signal feature  correlation matrix
# Background feature  correlation matrix

# %%
from HiggsML.visualization import stacked_histogram

stacked_histogram(data_set, target, weights, detailed_label, "PRI_jet_subleading_pt")
# Out:
# keys ['diboson' 'htautau' 'ttbar' 'ztautau']
# keys 2 dict_keys(['diboson', 'htautau', 'ttbar', 'ztautau'])
# htautau (30,)

# %%
from HiggsML.visualization import pair_plots

# Show data summary
pair_plots(
    data_set,
    target,
    sample_size=100,
    columns=[
        "PRI_lep_phi",
        "PRI_met",
        "DER_lep_eta_centrality",
        "DER_deltaeta_jet_jet",
    ],
)

# %%
from feature_analysis import Score_systematics
Score_systematics(data,True)

# %% [markdown]
# ### Ingestion

# %%
from sample_code_submission import neural_network

print(neural_network.__file__)
# Out:
# /content/Alpaca-new/Higgs_collaborations/sample_code_submission/neural_network.py

# %%
from HiggsML.ingestion import Ingestion

ingestion = Ingestion(data)

# %%
# initialize submission
ingestion.init_submission(Model,"BDT")
# Out:
# Training Data:  (5000, 28)
# Training Labels:  (5000,)
# Training Weights:  (5000,)
# sum_signal_weights:  651.6439824818337
# sum_bkg_weights:  105067.35601751815
#
# Valid Data:  (5000, 28)
# Valid Labels:  (5000,)
# Valid Weights:  (5000,)
# sum_signal_weights:  683.531936665967
# sum_bkg_weights:  105035.468063334
#
# Holdout Data:  (5000, 28)
# Holdout Labels:  (5000,)
# Holdout Weights:  (5000,)
# sum_signal_weights:  666.4066713454258
# sum_bkg_weights:  105052.59332865459
#
#
# Training Data:  (5000, 28)
# DEBUG: model_type = 'NN'
#  Model is NN

# %%
model_dir = "/content/Alpaca-new/Higgs_collaborations/sample_code_submission"

print("Existe ?", os.path.exists(model_dir))

for f in os.listdir(model_dir):
    print(f)
# Out:
# Existe ? True
# hist_plot.py
# scaler.pkl
# hist_plot_bin_per_bin.py
# model.py
# hist_plot_bin_per_bin_BKG.py
# utils.py
# dico.py
# neural_network.py
# neural_network_bis.py
# feature_analysis.py
# BDT
# systematic_analysis.py
# boosted_decision_tree.py
# __pycache__
# diagnostic_scores_hors_intervalle.md
# statistical_analysis.py
# sample_model.py
# model.keras

# %%
# fit submission
ingestion.fit_submission()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5544/1236975496.py in <cell line: 0>()
#       1 # fit submission
# ----> 2 ingestion.fit_submission()
#
# /usr/local/lib/python3.12/dist-packages/HiggsML/ingestion.py in fit_submission(self)
#     139         """
#     140         logger.info("Calling fit method of submitted model")
# --> 141         self.model.fit()
#     142
#     143     def predict_submission(self, test_settings, initial_seed=DEFAULT_INGESTION_SEED):
#
# /content/Alpaca-new/Higgs_collaborations/sample_code_submission/model.py in fit(self)
#     190         balanced_set["weights"] = weights_train
#     191
# --> 192         self.model.fit(
#     193             balanced_set["data"], balanced_set["labels"], balanced_set["weights"]
#     194         )
#
# /content/Alpaca-new/Higgs_collaborations/sample_code_submission/neural_network.py in fit(self, train_data, y_train, weights_train)
#      78         model_path = os.path.join(model_dir, "model.pt")
#      79         scaler_path = os.path.join(model_dir, "scaler.pkl")
# ---> 80         self.scaler = joblib.load(scaler_path)
#      81         self.model = self.build_model()
#      82         self.model.load_state_dict(torch.load(model_path, map_location="cpu"))
#
# /usr/local/lib/python3.12/dist-packages/joblib/numpy_pickle.py in load(filename, mmap_mode, ensure_native_byte_order)
#     733             obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734     else:
# --> 735         with open(filename, "rb") as f:
#     736             with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737                 fobj,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/higgs_nn/scaler.pkl'

# %%
# load test set
data.load_test_set()

# %% [markdown]
# ### Test Settings
# The Test setting sets the test conditions in ingestion.
# This includes what systematics you want and how many psuedo experiments you want.

# %%
test_settings = {
    "systematics": {  # Systematics to use
        "tes": False,  # tau energy scale
        "jes": False,  # jet energy scale
        "soft_met": False,  # soft term in MET
        "ttbar_scale": False,  # W boson scale factor
        "diboson_scale": False,  # Diboson scale factor
        "bkg_scale": False,  # Background scale factor
    },
    "num_pseudo_experiments": 500,  # Number of pseudo-experiments to run per set
    "num_of_sets": 1,  # Number of sets of pseudo-experiments to run
}

RANDOM_SEED = 42

random_state = np.random.RandomState(RANDOM_SEED)
test_settings["ground_truth_mus"] = (
    random_state.uniform(0.1, 3, test_settings["num_of_sets"])
).tolist()

random_settings_file = os.path.join(output_dir, "test_settings.json")
with open(random_settings_file, "w") as f:
    json.dump(test_settings, f)

# %%
# predict submission
ingestion.predict_submission(test_settings)

# %%
ingestion.process_results_dict()

# %%
# save result
ingestion.save_result(output_dir)

# %% [markdown]
# ## Score
# 1. Compute Scores
# 2. Visualize Scores

# %%
from HiggsML.score import Scoring

# %%
# Initialize Score
score = Scoring()

# %%
print(output_dir)
score.load_ingestion_results(prediction_dir=output_dir, score_dir=output_dir)

# %%
# Compute Score
score.compute_scores(test_settings)

# %%
from HiggsML.visualization import visualize_scatter

# Visualize scatter plot of ground truth mu and predicted mu
visualize_scatter(
    ingestion_result_dict=ingestion.results_dict,
    ground_truth_mus=test_settings["ground_truth_mus"],
)

# %%
# !python -m HiggsML.score --prediction $output_dir --output $output_dir
